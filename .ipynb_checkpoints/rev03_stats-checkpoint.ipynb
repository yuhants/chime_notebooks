csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr218.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr837.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr696.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr185.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr941.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr325.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr678.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr477.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr898.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr513.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr82.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr982.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr406.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr920.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr903.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr116.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr803.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr198.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr594.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr1002.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr522.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr940.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr780.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr481.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr612.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr853.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr866.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr784.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr239.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr644.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr165.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr721.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr326.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr981.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr719.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr664.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr649.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr287.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr813.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr569.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr98.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr445.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr611.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr555.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr389.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr208.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr736.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr49.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr574.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr726.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr598.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr496.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr467.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr546.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr697.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr148.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr558.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr737.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr579.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr916.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr9.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr151.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr550.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr919.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr209.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr974.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr14.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr196.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr297.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr490.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr450.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr1003.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr635.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr823.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr969.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr930.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr869.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr65.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr40.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr978.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr680.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr758.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr608.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr540.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr509.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr158.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr508.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr68.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr924.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr409.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr293.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr99.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr533.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr288.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr457.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr638.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr23.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr483.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr428.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr33.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr887.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr253.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr235.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr564.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr733.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr97.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr342.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr425.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr408.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr908.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr807.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr830.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr159.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr772.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr572.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr801.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr478.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr396.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr506.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr820.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr746.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr126.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr484.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr959.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr77.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr59.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr942.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr972.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr382.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr375.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr207.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr802.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr162.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr633.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr439.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr94.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr766.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr861.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr655.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr247.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr990.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr20.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr551.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr768.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr538.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr446.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr268.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr426.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr438.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr272.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr586.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr334.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr422.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr904.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr749.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr395.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr475.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr169.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr19.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr64.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr647.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr799.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr665.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr659.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr246.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr213.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr53.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr776.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr400.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr491.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr221.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr998.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr962.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr1018.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr937.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr101.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr913.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr769.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr44.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr386.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr360.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr377.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr108.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr817.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr891.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr529.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr346.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr317.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr187.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr790.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr1022.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr535.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr181.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr60.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr637.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr323.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr111.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr795.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr343.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr384.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr1004.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr792.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr822.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr176.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr493.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr935.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr947.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr314.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr122.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr639.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr135.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr357.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr842.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr12.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr444.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr175.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr985.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr614.csv',
#  '/home/yuhants/ringmap_stats/rev03/CSD_stats_out_fr821.csv',
#  ...]

# %%
def get_freq(file_name):
    """Return frequency according to file name"""
    nums = re.findall(r'\d+', file_name)  # Find regular expression of any non-zero number of digits
    if (nums[0] == '03' and len(nums)==2): # "nums" are in the format ['03', freq]
        return int(nums[1])
    else:
        return None

# %%
stats = {get_freq(f) : f for f in stats_files}  # Dictionary, key = frequency
dat = pd.read_csv(stats[107], header = 0, sep = ',')  # 758 MHz

# %%
mean = dat['mean']
stdev = dat['stdev']
delta = np.square(stdev) + np.square(mean)  # E[X^2], square of the differenced map
dat.insert(loc=3, column='delta', value=delta)  # Insert an extra column to the DataFrame

# %%
dat
# Out:
#         CSD      mean    median       delta      stdev        skew  \
# 0    2183.0  0.001217  0.000776    1.092395   1.045176 -268.724085
# 1    2170.0  0.000782  0.000696    1.778096   1.333453   22.555689
# 2    1989.0 -0.000594 -0.000402    0.059179   0.243268   98.841586
# 3    2102.0  0.000823  0.000383  162.957425  12.765478   12.251337
# 4    1842.0 -0.002014 -0.000786    2.249075   1.499690  -23.144054
# ..      ...       ...       ...         ...        ...         ...
# 306  2254.0  0.001845  0.002801    0.014406   0.120011  -40.399512
# 307  2200.0  0.000388 -0.000138    0.928063   0.963360   26.870868
# 308  1905.0  0.001239 -0.000355    0.203811   0.451453    3.176187
# 309  2051.0  0.000248  0.000337    0.380670   0.616984    4.333457
# 310  2225.0  0.000767  0.000457    0.485306   0.696639  107.417636
#
#           kurtosis      zsum   nonzero
# 0    110378.384195  0.059930  0.574463
# 1      5214.450545  0.047266  0.518799
# 2     27148.933829  0.174438  0.379883
# 3      4569.789867  0.044379  0.272949
# 4     36783.636463  0.088699  0.437744
# ..             ...       ...       ...
# 306    9397.296459  0.427269  0.051025
# 307    6823.638541  0.064822  0.492188
# 308   15425.227378  0.133621  0.582764
# 309   31970.026790  0.087183  0.280762
# 310   25534.923758  0.078637  0.599609
#
# [311 rows x 9 columns]

# %%
sns.set(font_scale=2, palette='gray')
sns.pairplot(dat, kind='scatter', height=4, aspect=1, corner=True)

# %% [markdown]
# Here are some interesting observations and points to think about:
# 1. KDE plots can be misleading for highly non-Gaussian or multimodal distributions. For example, the "nonzero-CSD" plot looks funny in KDE but is really an effect of daytime masking due to diurnal cycle.
# 2. For all the stats, data cluster around 0 has higher values of "nonzero". This means that ringmaps with smaller amount of data left after processing are of lower quality.
# 3. There is an interesting linear correlation between mean and median. Why? --might be the distribution is just really symmetric
# 4. Is it better to calculate against mean (std, skew, kurtosis) or against template (delta and its yet-to-be-calculated similars)?
# 5. There is a "flipped" positive correlation between skew and kurtosis. It seems like they are probing the same feature of the data.

# %% [markdown]
# ## Identify outliers

# %%
sns.reset_orig()

def histogram(data, bins='fd', range=None):
    """Compute the histogram of a dataset"""
    data = data[~np.isnan(data)]
    hist, bin_edges = np.histogram(data, bins, range, density=False)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2.
    return hist, bin_centers

# %%
# Cast columns to numpy arrays
# We now have numpy arrays 'CSD', 'mean', 'median', 'delta',
# 'stdev', 'skew', 'kurtosis', 'zsum', and 'nonzero'
print(dat.keys())
for key in dat.keys():
    globals()[key] = dat[key].to_numpy()
# Out:
# Index(['CSD', 'mean', 'median', 'delta', 'stdev', 'skew', 'kurtosis', 'zsum',
#        'nonzero'],
#       dtype='object')

# %%
def plot_hist(ax, data, bins=100, range=None, title=None, ylabel=True):
    ax.hist(data, color = 'k', histtype = 'step', 
             bins=bins, range=range, density = False)
    ax.set_ylabel('Count')
    
    if title is not None:
        ax.set_title(title)
        
    if ylabel == False:
        ax.set_ylabel('')

# %%
stat = ['mean', 'median', 'delta', 'stdev', 'skew', 'kurtosis']
fig = plt.figure(figsize=(12, 7))
for i in range(len(stat)):
    data = globals()[stat[i]]
    
    ax = fig.add_subplot(231+i)
    
    if i != 3: ylabel = False
    else: ylabel=True
    
    if stat[i] != 'delta': title=stat[i]
    else: title=r'$(\Sigma_i \ x^2_i) / N$'
    plot_hist(ax, data, bins='fd', title=title, ylabel=ylabel)

# %% [markdown]
# In previous work people fit gaussian to the binned histogram. This approach is intuitive but nonideal. Because the fitting depends on the choice of binning scheme, we cannot consistently estimate the "location" and "scale" of the distribution.

# %%
from scipy.optimize import curve_fit

def gauss(x, sigma, mu, N):
    return N * np.exp(- 0.5 * ((x-mu)/sigma)**2)

def gaussian_fit(data):
    n, mid_bin = histogram(data)
    (sigma, mu, N), pcov = curve_fit(gauss, mid_bin, n)
    return sigma, mu, N

# %%
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot(111)
plot_hist(ax, mean, 'fd', title='Mean')

n, mid_bins = histogram(mean)
x = np.linspace(mid_bins[0], mid_bins[-1], 1000)
sigma, mu, N = gaussian_fit(mean)
ax.plot(x, gauss(x, sigma, mu, N), color='green', label='Gaussian Fit')
print('mu:', mu)
print('sigma:', sigma)
print(N)
# Out:
# mu: 0.0004241403915755336
# sigma: 0.0006994104528751129
# 51.104571825373945

# %% [markdown]
# A better way is to simply calculate mean and standard deviation - they are really what we get if least-square "fitting" the unbinned data. Or put it in another way, the maximum likelihood solution for a guassian likelihood.

# %%
_ = mean[~np.isnan(mean)]
print('Mean:', np.mean(_))
print('STD:', np.std(_))
# Out:
# Mean: 0.00033915110325203837
# STD: 0.0021452287324957133

# %% [markdown]
# However, mean and std are not robust in the presence of outliers (can be seen from their deviation from values given by histogram fitting). An alternative way is using median and interquartile range (IQR).

# %% [markdown]
# A conventional "definition" for outliers:
#
# data outside of the range (lower, upper) = (q25 - 1.5 $\times$ IQR, q75+1.5 $\times$ IQR)
#
# This correspond to ~2.7 sigma for a normal distribution

# %%
q75, q25 = np.percentile(_, [75 ,25])
iqr = q75 - q25
print('Median', np.median(_))
print('Normalized Interquartile Range:', 0.7413 * iqr)
# Out:
# Median 0.00040534977074650703
# Normalized Interquartile Range: 0.0008528596993104476

# %%
def get_outliers(dat, stat, method='iqr'):
    """Return outliers in terms of CSDs"""
    data = dat[stat].to_numpy()
    _ = data[~np.isnan(data)]
    
    if method == 'iqr':
        q75, q25 = np.percentile(_, [75 ,25])
        iqr = q75 - q25
        lower, upper = q25 - 1.5*iqr, q75 + 1.5*iqr
        outliers_l = dat['CSD'][dat[stat] < lower]
        outliers_u = dat['CSD'][dat[stat] > upper]
        
        return outliers_l.to_numpy(), outliers_u.to_numpy()

    else:
        pass

# %%
(lower, upper) = q25-1.5*iqr, q75+1.5*iqr
print(lower, upper)
low, high = _[_<lower], _[_>upper]
# Out:
# -0.0020719882852494485 0.002529979605269627

# %%
print(low.shape, high.shape)
print(low)
print(high)
# Out:
# (14,) (10,)
# [-0.00456042 -0.00215066 -0.00218276 -0.00276712 -0.00303526 -0.00272141
#  -0.00400991 -0.00223977 -0.00289266 -0.00340801 -0.00228567 -0.00683733
#  -0.00304823 -0.00385687]
# [0.02571808 0.00632751 0.00351779 0.01315433 0.00545971 0.00930205
#  0.00307902 0.00437947 0.00346674 0.00429039]

# %%
for stat in ['mean', 'median', 'skew']:
    globals()['out_'+stat] = np.sort(np.concatenate(get_outliers(dat, stat)))

# %%
print(out_mean)
print(out_median)
print(out_skew)
# Out:
# [1813. 1814. 1815. 1816. 1839. 1840. 1841. 1877. 2015. 2034. 2036. 2129.
#  2136. 2149. 2162. 2177. 2220. 2223. 2247. 2250. 2251. 2252. 2253. 2263.]
# [1813. 1816. 1839. 1840. 2015. 2034. 2100. 2162. 2177. 2220. 2223. 2247.
#  2250. 2251. 2252. 2253. 2254. 2255. 2263.]
# [1797. 1806. 1810. 1812. 1813. 1959. 1998. 2026. 2028. 2034. 2075. 2093.
#  2096. 2110. 2117. 2118. 2119. 2131. 2136. 2140. 2141. 2142. 2143. 2144.
#  2145. 2146. 2149. 2163. 2164. 2165. 2168. 2169. 2172. 2181. 2182. 2183.
#  2220. 2251. 2252. 2253. 2263.]

# %%
csd = np.sort(CSD)

# %%
count = np.zeros_like(csd)
for o in [out_mean, out_median, out_skew]:
    plt.barh(o, np.ones_like(o), left=count[np.isin(csd, o)])
    count[np.isin(csd, o)] += 1
